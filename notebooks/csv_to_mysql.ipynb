# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
USER = "root"
PASSWORD = "0915172023"
HOST = "127.0.0.1"
PORT = "3306"
DATABASE = "cvm_dados"

conn = mysql.connector.connect(
    host=HOST,
    user=USER,
    password=PASSWORD
)
cursor = conn.cursor()

cursor.execute(f"CREATE DATABASE IF NOT EXISTS {DATABASE}")
conn.close()

engine = create_engine(
    f"mysql+mysqlconnector://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

# %%
df.head()
# Out:
#              cnpj_cia    dt_refer  versao  \
# 0  02.635.522/0001-95  2025-03-31       1
# 1  02.635.522/0001-95  2025-03-31       1
# 2  02.635.522/0001-95  2025-03-31       1
# 3  06.981.381/0001-13  2025-03-31       1
# 4  06.981.381/0001-13  2025-03-31       1
#
#                                     denom_cia  cd_cvm  \
# 0                         JALLES MACHADO S.A.   25496
# 1                         JALLES MACHADO S.A.   25496
# 2                         JALLES MACHADO S.A.   25496
# 3  CTC - CENTRO DE TECNOLOGIA CANAVIEIRA S.A.   23981
# 4  CTC - CENTRO DE TECNOLOGIA CANAVIEIRA S.A.   23981
#
#                                     grupo_dfp moeda escala_moeda ordem_exerc  \
# 0  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL      ÚLTIMO
# 1  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL      ÚLTIMO
# 3  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL      ÚLTIMO
# 4  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL      ÚLTIMO
#
#   dt_fim_exerc cd_conta                       ds_conta      vl_conta  \
# 0   2025-03-31        1                    Ativo Total  7.137606e+09
# 1   2025-03-31     1.01               Ativo Circulante  2.301201e+09
# 2   2025-03-31  1.01.01  Caixa e Equivalentes de Caixa  1.237342e+09
# 3   2025-03-31        1                    Ativo Total  1.447937e+09
# 4   2025-03-31     1.01               Ativo Circulante  6.842260e+08
#
#   st_conta_fixa
# 0             S
# 1             S
# 2             S
# 3             S
# 4             S

# %%
df = pd.read_csv("../data/dado_tratado/bpa_tratado.csv")

df.columns = [
    "cnpj_cia",
    "dt_refer",
    "versao",
    "denom_cia",
    "cd_cvm",
    "grupo_dfp",
    "moeda",
    "escala_moeda",
    "ordem_exerc",
    "dt_fim_exerc",
    "cd_conta",
    "ds_conta",
    "vl_conta",
    "st_conta_fixa"
]

# %%
df.to_sql(
    "demonstrativos",
    con=engine,
    if_exists="replace",
    index=False
)

print("✅ Banco criado, tabela criada e CSV carregado com sucesso")
# Out:
# ✅ Banco criado, tabela criada e CSV carregado com sucesso
